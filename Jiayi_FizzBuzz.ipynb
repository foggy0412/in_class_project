# %% [markdown]
# # In class lab on June 13 2018
#
# Flow Control: Fizzbuzz
# FizzBuzz is a class computer science interview problem. Create a script that completes the following tasks:
# Prints numbers from 1 to 100, one number per row
# If a number is divisible by 3, print "Fizz" (for example, "3 = Fizz!"
# If a number is divisible by 5, print "Buzz"
# If a number is divisible by both 3 and 5, print "FizzBuzz!"
# Once you've figured out the basic FizzBuzz logic, turn it into a function that will work for any start and stop number.
# There are many different ways to approach this problem, but here are a few things to keep in mind:
# What function can you use to create a list of numbers within the range of 1 to 100? Is 100 included in that list?
# What math operator can you use to tell if a number is divisible by something?
# How can you use flow control (if, else) and operators (==, etc.) to deal with this problem?
# What order should things happen in to ensure your program checks all the things it needs to, but does so efficiently?

# %%
def FizzBuzz(start_number, stop_number):
    num_list = list(range(start_number,stop_number+1,1))
    for n in num_list:
        if n % 3 == 0 and n % 5 == 0:
            print(n," FizzBuzz")
        elif n % 3 == 0 :
            print(n, "Fizz")
        elif n % 5 == 0:
            print(n, "Buzz")
        else:
            print(n)

FzBz = FizzBuzz(3,199)
Fzbz
# Out:
# 3 Fizz
# 4
# 5 Buzz
# 6 Fizz
# 7
# 8
# 9 Fizz
# 10 Buzz
# 11
# 12 Fizz
# 13
# 14
# 15  FizzBuzz
# 16
# 17
# 18 Fizz
# 19
# 20 Buzz
# 21 Fizz
# 22
# 23
# 24 Fizz
# 25 Buzz
# 26
# 27 Fizz
# 28
# 29
# 30  FizzBuzz
# 31
# 32
# 33 Fizz
# 34
# 35 Buzz
# 36 Fizz
# 37
# 38
# 39 Fizz
# 40 Buzz
# 41
# 42 Fizz
# 43
# 44
# 45  FizzBuzz
# 46
# 47
# 48 Fizz
# 49
# 50 Buzz
# 51 Fizz
# 52
# 53
# 54 Fizz
# 55 Buzz
# 56
# 57 Fizz
# 58
# 59
# 60  FizzBuzz
# 61
# 62
# 63 Fizz
# 64
# 65 Buzz
# 66 Fizz
# 67
# 68
# 69 Fizz
# 70 Buzz
# 71
# 72 Fizz
# 73
# 74
# 75  FizzBuzz
# 76
# 77
# 78 Fizz
# 79
# 80 Buzz
# 81 Fizz
# 82
# 83
# 84 Fizz
# 85 Buzz
# 86
# 87 Fizz
# 88
# 89
# 90  FizzBuzz
# 91
# 92
# 93 Fizz
# 94
# 95 Buzz
# 96 Fizz
# 97
# 98
# 99 Fizz
# 100 Buzz
# 101
# 102 Fizz
# 103
# 104
# 105  FizzBuzz
# 106
# 107
# 108 Fizz
# 109
# 110 Buzz
# 111 Fizz
# 112
# 113
# 114 Fizz
# 115 Buzz
# 116
# 117 Fizz
# 118
# 119
# 120  FizzBuzz
# 121
# 122
# 123 Fizz
# 124
# 125 Buzz
# 126 Fizz
# 127
# 128
# 129 Fizz
# 130 Buzz
# 131
# 132 Fizz
# 133
# 134
# 135  FizzBuzz
# 136
# 137
# 138 Fizz
# 139
# 140 Buzz
# 141 Fizz
# 142
# 143
# 144 Fizz
# 145 Buzz
# 146
# 147 Fizz
# 148
# 149
# 150  FizzBuzz
# 151
# 152
# 153 Fizz
# 154
# 155 Buzz
# 156 Fizz
# 157
# 158
# 159 Fizz
# 160 Buzz
# 161
# 162 Fizz
# 163
# 164
# 165  FizzBuzz
# 166
# 167
# 168 Fizz
# 169
# 170 Buzz
# 171 Fizz
# 172
# 173
# 174 Fizz
# 175 Buzz
# 176
# 177 Fizz
# 178
# 179
# 180  FizzBuzz
# 181
# 182
# 183 Fizz
# 184
# 185 Buzz
# 186 Fizz
# 187
# 188
# 189 Fizz
# 190 Buzz
# 191
# 192 Fizz
# 193
# 194
# 195  FizzBuzz
# 196
# 197
# 198 Fizz
# 199
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d34370e4292> in <module>
#      12
#      13 FzBz = FizzBuzz(3,199)
# ---> 14 Fzbz
#
# NameError: name 'Fzbz' is not defined
